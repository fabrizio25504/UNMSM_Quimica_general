# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrizio25504/UNMSM_Quimica_general/blob/main/PC_Gases_parte2(Fabrizio_Mantari).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install drawdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 11.0 MB/s eta 0:00:00
# ...

# %%
from drawdata import draw_scatter, draw_histogram, draw_line

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# debes hacer la grafica acorde a lo q piden solo busca en google como son las graficas de lo q te piden

# %%
df = pd.read_csv("data.csv")
df
# Out:
#               x           y  z
# 0      9.569646  488.974458  a
# 1     15.414963  545.025628  a
# 2     22.113316  489.167977  a
# 3     15.307367  473.523416  a
# 4     56.283871  463.661631  a
# ..          ...         ... ..
# 203  672.066439   39.197613  a
# 204  697.372935   25.857332  a
# 205  756.935365   -3.101135  a
# 206  724.621449   76.750644  a
# 207  711.436939   49.346287  a
#
# [208 rows x 3 columns]

# %%
# para cambiar los nombres de las columnas
df = df.rename(columns={'x': 'Volumen', 'y': 'Presion'})
df
# Out:
#         Volumen     Presion  z
# 0      9.569646  488.974458  a
# 1     15.414963  545.025628  a
# 2     22.113316  489.167977  a
# 3     15.307367  473.523416  a
# 4     56.283871  463.661631  a
# ..          ...         ... ..
# 203  672.066439   39.197613  a
# 204  697.372935   25.857332  a
# 205  756.935365   -3.101135  a
# 206  724.621449   76.750644  a
# 207  711.436939   49.346287  a
#
# [208 rows x 3 columns]

# %%
#df["1/Volumen"] = 1/df["1/Volumen"]
#df.to_csv("df.csv")
#df["1/Volumen"]
# Out:
# 0        9.569646
# 1       15.414963
# 2       22.113316
# 3       15.307367
# 4       56.283871
#           ...
# 203    672.066439
# 204    697.372935
# 205    756.935365
# 206    724.621449
# 207    711.436939
# Name: 1/Volumen, Length: 208, dtype: float64

# %%
plt.scatter(df["Volumen"],df["Presion"])
plt.ylabel("Presion")
plt.xlabel("V")
# Out:
# Text(0.5, 0, 'V')

# %%
# !pip install scipy

# %%
from scipy import stats

# %%
x = df["Volumen"]
y = df["Presion"]

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(f"Ecuación de la línea de regresión: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Ecuación de la línea de regresión: y = -0.56x + 325.71

# %%
plt.scatter(x, y)
plt.plot(x, slope * x + intercept, label="Línea de Regresión", color="red")
plt.ylabel("Presión")
plt.xlabel("Volumen")
plt.legend()
plt.show()

# %% [markdown]
# **Ley de Gay lussac**

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df1 = pd.read_csv("data (1).csv")
df1
# Out:
#               x           y  z
# 0     70.233121   14.666946  a
# 1      9.816752   38.512930  a
# 2      5.587291    7.306913  a
# 3     21.053857  -20.057919  a
# 4      0.708242    4.865448  a
# ..          ...         ... ..
# 178  728.305113  476.737775  a
# 179  657.178934  461.380514  a
# 180  705.413161  454.008487  a
# 181  709.738210  443.635793  a
# 182  679.055739  455.923690  a
#
# [183 rows x 3 columns]

# %%
df1 = df1.rename(columns={ 'x': 'T' , 'y':'P'})
df1
# Out:
#               T           P  z
# 0     70.233121   14.666946  a
# 1      9.816752   38.512930  a
# 2      5.587291    7.306913  a
# 3     21.053857  -20.057919  a
# 4      0.708242    4.865448  a
# ..          ...         ... ..
# 178  728.305113  476.737775  a
# 179  657.178934  461.380514  a
# 180  705.413161  454.008487  a
# 181  709.738210  443.635793  a
# 182  679.055739  455.923690  a
#
# [183 rows x 3 columns]

# %%
plt.scatter(df1["T"],df1["P"])
plt.ylabel("Presion(ATM)")
plt.xlabel("T(celsius)")
# Out:
# Text(0.5, 0, 'T(celsius)')

# %%
x1= df1["T"]
y1 = df1["P"]

slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print(f"Ecuación de la línea de regresión: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Ecuación de la línea de regresión: y = 0.70x + -1.97

# %%
plt.scatter(x1, y1)
plt.plot(x1, slope * x1 + intercept, label="Línea de Regresión", color="red")
plt.ylabel("Presión(ATM)")
plt.xlabel("Temperatura(Celsius)")
plt.legend()
plt.show()

# %% [markdown]
# **Ley de Charles**

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df2 = pd.read_csv("data (2).csv")
#el rename no cambia el data frame directamente sino que devuelve uno nuevo
df2 = df2.rename(columns={'x':'T', 'y':'V'})
df2
# Out:
#               T           V  z
# 0    -23.421010   30.983461  a
# 1      2.995499  -16.654840  a
# 2      0.322862   36.161888  a
# 3     38.473305   31.998316  a
# 4     32.142951  -27.959877  a
# ..          ...         ... ..
# 109  678.738114  459.186289  a
# 110  698.378100  498.822904  a
# 111  682.017449  489.610787  a
# 112  696.511783  500.067566  a
# 113  729.394143  471.334587  a
#
# [114 rows x 3 columns]

# %%
x2 = df2["T"]
y2 = df2["V"]

slope, intercept, r_value, p_value, std_err = stats.linregress(x2, y2)
print(f"Ecuación de la línea de regresión: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Ecuación de la línea de regresión: y = 0.72x + -24.50

# %%
plt.scatter(x2, y2)
plt.plot(x2, slope * x2 + intercept, label="Línea de Regresión", color="red")
plt.ylabel("Presión(ATM)")
plt.xlabel("Temperatura(Celsius)")
plt.legend()
plt.show()

# %% [markdown]
# Velocidad vs # de moléculas

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df3 = pd.read_csv("data (3).csv")
df3
# Out:
#          x         y  z
# 0    0.000  0.033328  a
# 1    0.025  0.331328  a
# 2    0.050  0.539328  a
# 3    0.075  0.539328  a
# 4    0.100  0.915328  a
# ..     ...       ... ..
# 115  0.875  0.077328  c
# 116  0.900  0.065328  c
# 117  0.925  0.051328  c
# 118  0.950  0.047328  c
# 119  0.975  0.047328  c
#
# [120 rows x 3 columns]

# %%
# Esta funcion agrupa todos los elementos similares en una columna del dataframe
grupos = df3.groupby("z")

for nombre, grupo in grupos:
    print(f"Estadísticas descriptivas para el grupo {nombre}:")
    print(grupo.describe())
    print()
# Out:
# Estadísticas descriptivas para el grupo a:
#                x          y
# count  40.000000  40.000000
# mean    0.487500   0.231178
# std     0.292261   0.214812
# min     0.000000   0.017328
# 25%     0.243750   0.093828
# 50%     0.487500   0.165328
# 75%     0.731250   0.260828
# max     0.975000   0.915328
#
# Estadísticas descriptivas para el grupo b:
#                x          y
# count  40.000000  40.000000
# mean    0.487500   0.222078
# std     0.292261   0.176108
# min     0.000000   0.009328
# 25%     0.243750   0.061328
# 50%     0.487500   0.171328
# 75%     0.731250   0.385828
# max     0.975000   0.507328
#
# Estadísticas descriptivas para el grupo c:
#                x          y
# count  40.000000  40.000000
# mean    0.487500   0.181728
# std     0.292261   0.110200
# min     0.000000   0.003328
# 25%     0.243750   0.087828
# 50%     0.487500   0.163328
# 75%     0.731250   0.284328
# max     0.975000   0.349328

# %% [markdown]
# Pregunta 2:

# %%
# !pip install pdfplumber
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 79.7 MB/s eta 0:00:00
# ...

# %%
url = 'https://datosmacro.expansion.com/energia-y-medio-ambiente/emisiones-co2/chile'
tablas = pd.read_html(url)
tablas
# Out:
# [    Fecha  CO2 Totales Mt  CO2 Kg/1000$  CO2 t per capita
#  0    2021           85703          17.0               461
#  1    2020           83495          19.0               452
#  2    2019           94010          20.0               513
#  3    2018           89060          19.0               489
#  4    2017           89340          20.0               495
#  5    2016           88570          20.0               495
#  6    2015           84066          19.0               473
#  7    2014           78470          18.0               446
#  8    2013           84988          20.0               487
#  9    2012           80850          20.0               467
#  10   2011           78661          21.0               459
#  11   2010           72065          20.0               424
#  12   2009           67946          20.0               404
#  13   2008           71012          21.0               426
#  14   2007           67465          20.0               409
# ...

# %%
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
plt.bar(tablas[0]['Fecha'],tablas[0]['CO2 Totales Mt'])
# Out:
# <BarContainer object of 52 artists>

# %%
import numpy as np

# Calcular la media de los datos en la columna 'CO2 Totales Mt'
media = np.mean(tablas[0]['CO2 Totales Mt'])

# Calcular la mediana de los datos en la columna 'CO2 Totales Mt'
mediana = np.median(tablas[0]['CO2 Totales Mt'])

# Calcular la moda de los datos en la columna 'CO2 Totales Mt'
moda = tablas[0]['CO2 Totales Mt'].mode().values[0]

# %%
print("la media es:",media)
print("la mediana es:",mediana)
print("la moda es :",moda)
# Out:
# la media es: 49268.32692307692
# la mediana es: 44383.5
# la moda es : 21587

# %%
tablas[0]['CO2 Totales Mt'].describe()
# Out:
# count       52.000000
# mean     49268.326923
# std      23511.934812
# min      21587.000000
# 25%      27856.500000
# 50%      44383.500000
# 75%      68712.500000
# max      94010.000000
# Name: CO2 Totales Mt, dtype: float64
