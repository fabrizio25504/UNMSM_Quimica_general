# %% [markdown]
# <a href="https://colab.research.google.com/github/fabrizio25504/UNMSM_Quimica_general/blob/main/PC_l%C3%ADquidos_y_soluciones(Mantari_Fabrizio).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Unidades de concentración**
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -El porcentaje en masa, es la masa de soluto que hay por cada 100 unidades de solución.
#
# -La fracción molar, es la relación que hay entre las moles o del soluto o solvente respecto a las moles de la solución.
#
# -La molaridad, es el número de moles disuelto por litro de disolución, su unidad es mol/L o M.
#
# -La molalidad expresa que se disuelve por kilogramo de disolución, sus unidades son mol/Kg o m.
#
# Entre la molaridad y la molalidad a veces puedes ser mas ventajosa la molalidad pues esta no se verá afectada por los cambios de temperatura o si quieres una relación adimensional podrías usar la fracción molar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#A
porcentaje_masa = (5.5/78.2)*100
print("el porcentaje de masa en la pregunta A es", round(porcentaje_masa,2),"%")
#B
solucion = 31+152
porcentaje_masa2 = (31/solucion)*100
print("el porcentaje de masa en la pregunta B es", round(porcentaje_masa2,2),"%")
#C
solucion = 4.5+29
porcentaje_masa3 = (4.5/solucion)*100
print("el porcentaje de masa en la pregunta B es", round(porcentaje_masa3,2),"%")
# Out:
# el porcentaje de masa en la pregunta A es 7.03 %
# el porcentaje de masa en la pregunta B es 16.94 %
# el porcentaje de masa en la pregunta B es 13.43 %

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#A
porcentaje_masa = 16.2
soluto = 5
solvente = ((5*100)/porcentaje_masa)-soluto
print("La cantidad de agua (en gramos) necesaria en la pregunta A es", round(porcentaje_masa,2),"g")
#B
#A
porcentaje_masa = 1.5
soluto = 26.2
solvente = ((soluto*100)/porcentaje_masa)-soluto
print("La cantidad de agua (en gramos) necesaria en la pregunta B es", round(solvente,2),"g")
# Out:
# La cantidad de agua (en gramos) necesaria en la pregunta A es 16.2 g
# La cantidad de agua (en gramos) necesaria en la pregunta A es 1720.47 g

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#molalidad = mol soluto/solvente(Kg)
#mol = m/M
#A
molA = 14.3/(12*12 + 22 + 11*16)
solvente = 676/1000
molalidad = molA/solvente
print(f"La molalidad en la pregunta A es {molalidad:2f} mol/Kg")
#B
molB = 7.2
solvente = 3546/1000
molalidad = molB/solvente
print(f"La molalidad en la pregunta A es {molalidad:2f} mol/Kg")
# Out:
# La molalidad en la pregunta A es 0.061853 mol/Kg
# La molalidad en la pregunta A es 2.030457 mol/Kg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#molalidad = mol soluto/solvente(Kg)
#mol = m/M
#densidad = m(disolución)/V
#molaridad = moles de soluto / Litros de solución
#A
molaridad = 2.5
densidad = 1.08


#mol_soluto = masa_soluto/(23+35.5)
#reemplazamos en la molaridad: masa_soluto = 58.5*2.5/V(litro) <--- para este caso suponemos que tenemos 1 litro de solución
# por la densidad : 1.08 = masa_solucion(gramos)/V(ml)<--- 1000
#al suponer que el volumen es un litro las moles del soluto seran iguales a la molaridad
masa_soluto = 58.5*molaridad
masa_solucion = 1000*densidad
masa_solvente = (masa_solucion - masa_soluto)/1000 #para obtenerlo en kilogramos

molalidad = molaridad/masa_solvente
print("la molalidad en A es :", round(molalidad,2),"mol/kg")

#B
#nos dan el porcentaje en masa por lo que tenemos una relacion de masa_solucion/masa_soluto = 100/48.2(kg)
masa_solvente = 100 - 48.2
moles_soluto = 48.2/119 #119 es la masa molar del bromuro de potasio
molalidad = moles_soluto/masa_solvente
print("la molalidad en B es :", round(molalidad,3),"mol/kg")
# Out:
# la molalidad en A es : 2.68 mol/kg
# la molalidad en B es : 0.008 mol/kg

# %% [markdown]
# # **Soluciones**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esto quiere decir que las moleculas apolares se disolveran más facilmente con otras moleculas apolares(fuerzas dipolo - dipolo) y las moleculas polares con otras polares(fuerzas de dispersión).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por ejemplo al disolver la sal(NaCl) en agua
# el solvente separara gracias a las fuerzas dipolo-dipolo a la sal en cationes y aniones respectivamente.
# hasta que la sustancia ya no admita más soluto(solubilidad)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. La temperatura
# 2. La polarización
# 3. El tamaño del soluto
#
# Que dos liquidos sean miscibles signifca que estos se pueden diluir el uno al otro en cualquier cantidad sin importar las proporciones siempre se formara una sustancia homogenea.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---> más soluble CH3OH(polar con Puente de hidrogeno) > LiCl (dipolo_dipolo)> Br2(más radio = más polarizabilidad)> 02 <---- menos soluble

# %% [markdown]
# # **Efecto de la temperatura en la solubilidad**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
solubilidad_sal = 3.2/9.1
#si queremos que sea por cada 100 gramos de de agua debemos multiplicado por 100 sobre 100
solubilidad_sal *= 100
print("la solubilidad de la es",round(solubilidad_sal,2),"g(NaCl)/100g(H2O)")
# Out:
# la solubilidad de la es 35.16 g(NaCl)/100g(H2O)

# %% [markdown]
# # **Fuerzas intermoleculares**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A) LiCl
#
# B) NaCl + O2
#
# C)K+ y H2O
#
# D)Br2
#
# e)H2O

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La polarizabilidad es la capacidad con la cual la distribucion de electrones de una molecula se puede distorsionar.
#
# Las moleculas que tienen a ser polarizables tienen estas caracteristicas:
# - Poseen electrones deslocalizados (más electrones en la capa externa)
# - Moléculas con enlaces covalentes polares
# - Moléculas con estructura asimétrica
#
# La relación entre la polarizabilidad y las fuerzas moleculares principal mente se debe a las fuerzas dipolo dipolo pues esta fuerza se da entre 2 moleculas **polarizadas**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Los elementos que hacen enlace puente de hidrogeno son : Fluor, Oxigeno y Nitrogeno.
#
# El enlace puente de hidrogeno tiene caracteristicas unicas
# pues gracias a su elevada diferencia de electronegatividad genera un enlace muy fuerte a diferencia de las otras fuerzas de dispersión. Gracias a esto los compuestos formados con estos enlaces como el agua
# tiene caractericas unicas por ejemplo su elevado punto de ebullición y su importancia es vital para la vida pues forman parte de las proteínas y los acidos nucleicos,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# porque la principal diferencia entre estos 2 compuestos tiene que ver con los radios atomicos es decir una mayor dispersión de los electrones en el cloruro de yodo

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Recordemos que el punto de ebullición depende del radio atomico del elemento o compuesto y en este caso el periodo va en orden creciente lo que significa que del CH4 al SnH4 hay un aumento de radio creciente.

# %% [markdown]
# # **Propiedades de los líquidos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por qué los liquidos estan mucho mas compactos a diferencia de los gases y además sus moleculas interactuan constantemente(fuerzas intermoleculares) a diferencia de los gases.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Esto se debe a las fuerzas intermoleculares más especificamente la tensión superficial.
# Gracias a estas fuerzas las moleculas al borden del vaso son atraidas por las moleculas debajo de ellas y no solo sino tambien con el apoyo que generan estas moleculas con las moleculas del vaso(adhesión).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La viscosidad es la resistencia de un líquido a fluir, y es una propiedad que está relacionada con las fuerzas intermoleculares en el líquido.
#
#  La viscosidad es una medida de la fricción interna en un líquido que se opone al flujo de las moléculas. Cuanto más fuertes sean las fuerzas intermoleculares en un líquido, mayor será su viscosidad. Esta relación implica que la viscosidad puede variar con la temperatura, ya que las fuerzas intermoleculares suelen cambiar con la temperatura.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lo que pasa es que en el agua la energía cinetica permite que las moleculas de agua constante rompan y formen enlaces de hidrogeno, pero cuando la temperatura baja lo suficiente la energía cinetica sera menor que la fuerza de los enlaces de hidrogeno por lo que comenzaran a formar una estructura cristalina donde hay espacios entre si creando un mayor volumen con la misma cantidad de sustancia.
